# %%
#!/usr/bin/python3
import sys
from math import log2

if(len(sys.argv) != 2):
    #print("Usage: python3 halstead.py name_of_program")
    print("***halstead Metrix***")
    exit()

operatorsFileName = "halstead"
programFileName = "halstead.py"

operators = {}
operands = {}

with open(operatorsFileName) as f:
    for op in f:
        operators[op.replace('\n','')] = 0

isAllowed = True

with open(programFileName) as f:
    for line in f:
        line = line.strip("\n").strip(' ')

        if(line.startswith("/*")):
            isAllowed = False
       
        if((not line.startswith("//")) and isAllowed == True and (not line.startswith('#'))):
            for key in operators.keys():
                operators[key] = operators[key] + line.count(key)
                line = line.replace(key,' ')
            for key in line.split():
                if key in operands :
                    
                    operands[key] = operands[key] + 1
                else:
                    operands[key] = 1

        if(line.endswith("*/")):
            isAllowed = True


n1, N1, n2, N2 = 0, 0, 0, 0
n1, N1, n2, N2 = 1, 1, 1, 1

print("__________________OPERATORS______________:\n")
for key in operators:
    if(operators[key] > 0 ):
        if(key not in ")}]"):
            n1, N1 = n1 + 1, N1 + operators[key]
            print("{} = {}".format(key, operators[key]))

print("\n_________________OPERANDS_______________\n")
for key in operands.keys():
    if(operands[key] > 0 ):
        n2, N2 = n2 + 1, N2 + operands[key]
        print("{} = {}".format(key, operands[key]))

val = {"N": N1 + N2, "n": n1 + n2, "V": (N1 + N2) * log2(n1 + n2), "D": n1 * N2 / 2 / n2}
val['E'] = val['D'] * val['V']
val['L'] = val['V'] / val['D'] / val['D']
val['I'] = val['V'] / val['D']
val['T'] = val['E'] / (18)
val['N^'] = n1 * log2(n1) + n2 * log2(n2)
val['L^'] = 2 * n2 / N2 / n1

unit = {'V': 'bits', 'T': 'seconds'}
name = {'N':'Halstead Program Length', 'n':'Halstead Vocabulary', 'V':'Program Volume', 'D':'Program Difficulty', 'E': 'Programming Effort', 'L':'Language level', 'I':'Intelligence Content', 'T':'Programming time','N^':'Estimated program length', 'L^':'Estimated language level'}

print("\nThe various values are: ")
for key in val.keys():
    print("{} ({}) = {} {}".format(key,name[key], val[key], unit[key] if key in unit else ''))
# Out:
# ***halstead Metrix***
# __________________OPERATORS______________:
#
# " = 22
# if = 7
# for = 1
# import = 5
# while = 3
# < = 14
# > = 12
# + = 13
# else = 3
# , = 14
# == = 2
# = = 23
# try = 1
# { = 17
# [ = 9
# ( = 59
# ; = 56
# : = 5
# public = 7
# static = 3
# java = 5
# void = 1
# Scanner  = 5
# null = 3
# ! = 4
# return = 8
# true = 1
# false = 3
# int = 9
# && = 3
# getName = 2
# toString = 1
#
# _________________OPERANDS_______________
#
# .util.ArrayList = 1
# .util. = 1
# .io.File = 1
# .io.IOException = 1
# .util.Arrays = 1
# class = 2
# AirlineProblem = 1
# main = 1
# String = 23
# args = 1
# scannerToReadAirlines = 3
# new = 9
# File = 1
# airlines.txt = 1
# catch = 1
# IOException = 1
# e = 1
# System.out.pr = 6
# ln = 4
# Could = 1
# not = 1
# connect = 1
# to = 3
# file = 1
# airlines.txt. = 1
# System.exit = 1
# 0 = 5
# ArrayList = 11
# Airline = 7
# airlinesPartnersNetwork = 3
# newAirline = 3
# lineFromFile = 2
# airlineNames = 3
# scannerToReadAirlines.hasNext = 1
# scannerToReadAirlines.nextLine = 1
# lineFromFile.split = 1
# airlinesPartnersNetwork.add = 1
# keyboard = 1
# System.in = 1
# Enter = 2
# airline = 2
# miles = 3
# are = 1
# on = 1
# start = 3
# keyboard.nextLine = 2
# goal = 7
# pathForMiles = 5
# airlinesVisited = 4
# canRedeem = 3
# Path = 1
# redeem = 1
# Cannot = 1
# convert = 1
# from = 1
# . = 2
# private = 4
# boolean = 3
# current = 6
# network = 2
# current.equals = 1
# pathForMiles.add = 2
# airlinesVisited.contains = 1
# airlinesVisited.add = 1
# pos = 5
# -1 = 2
# index = 9
# network.size = 1
# network.get = 2
# .equals = 1
# - = 2
# 1 = 3
# partners = 6
# .getPartners = 1
# foundPath = 5
# partners.length = 1
# pathForMiles.remove = 1
# pathForMiles.size = 1
# name = 6
# data = 4
# assert = 1
# data.length = 2
# Failed = 1
# precondition = 1
# i = 4
# partners.add = 1
# getPartners = 1
# partners.toArray = 1
# partners.size = 1
# isPartner = 1
# partners.contains = 1
#
# The various values are:
# N (Halstead Program Length) = 557
# n (Halstead Vocabulary) = 125
# V (Program Volume) = 3879.9418465567824 bits
# D (Program Difficulty) = 42.14673913043478
# E (Programming Effort) = 163526.89684808612
# L (Language level) = 2.184224418879547
# I (Intelligence Content) = 92.05793678484177
# T (Programming time) = 9084.827602671452 seconds
# N^ (Estimated program length) = 766.6327058960742
# L^ (Estimated language level) = 0.02372662798194713

# %%
print("_________________OPERANDS_______________")
print("e = 1")
print("file = 1")
print("0 = 5")
print("miles = 3")
print("pos = 5")
print("-1 = 2")
print("index = 9")
print("1 = 3")
print("partners = 6")
print("name = 6")
print("data = 4")
print("i = 4")
# Out:
# _________________OPERANDS_______________
# e = 1
# file = 1
# 0 = 5
# miles = 3
# pos = 5
# -1 = 2
# index = 9
# 1 = 3
# partners = 6
# name = 6
# data = 4
# i = 4
